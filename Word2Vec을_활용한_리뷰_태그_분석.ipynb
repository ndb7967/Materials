# %% [markdown]
# #### <b>리뷰 태그 데이터 세트 분석</b>

# %%
# 압축 파일 해제
# !unzip w2v.zip
# Out:
# Archive:  w2v.zip
#   inflating: cluster_data.pickle
#   inflating: idx2word.pickle
#   inflating: sql_to_csv.py
#   inflating: train_data.pickle
#   inflating: word2idx.pickle
#   inflating: x.pickle
#   inflating: y.pickle

# %%
from itertools import permutations
import pickle

# 단어(word)를 인덱스(index)로 매핑한 사전 자료형
with open('./word2idx.pickle', 'rb') as f:
    word2idx = pickle.load(f)
print("총 단어의 수:", len(word2idx))

# 인덱스(index)를 단어(word)로 매핑한 사전 자료형
with open('./idx2word.pickle', 'rb') as f:
    idx2word = pickle.load(f)
print("총 인덱스의 수:", len(word2idx))

# 개별 리뷰에 담긴 태그에 대한 정보
# (전체 리뷰 개수 X 해당 리뷰의 태그 인덱스)의 크기를 가지는 2차원 리스트
with open('./cluster_data.pickle', 'rb') as f:
    cluster_data = pickle.load(f)

print(cluster_data[:5])
# Out:
# 총 단어의 수: 267
# 총 인덱스의 수: 267
# [[1, 2, 3], [4, 5, 1, 6, 7], [8, 7, 2], [3, 9, 2, 10], [7]]

# %% [markdown]
# * 현재 데이터 상으로 인덱스가 1부터 시작하므로, 총 데이터 크기를 268로 설정한다.

# %%
for i in range(5):
    review = cluster_data[i]
    print(f"[리뷰 {i + 1}] [", end='')
    for x in review[:-1]:
        print(idx2word[x], end=', ')
    print(idx2word[review[-1]] + "]")
# Out:
# [리뷰 1] [맞춤 케어를 잘해줘요, 친절해요, 매장이 청결해요]
# [리뷰 2] [주차하기 편해요, 좋은 제품을 사용해요, 맞춤 케어를 잘해줘요, 반려동물을 잘 다뤄줘요, 시술이 꼼꼼해요]
# [리뷰 3] [원하는 스타일로 잘해줘요, 시술이 꼼꼼해요, 친절해요]
# [리뷰 4] [매장이 청결해요, 상담이 자세해요, 친절해요, 손상이 적어요]
# [리뷰 5] [시술이 꼼꼼해요]

# %%
# 각 리뷰마다 2개의 태그가 서로를 정답으로 삼도록 학습 데이터 구성
original_train_dataset = []
for review in cluster_data:
    for tag in permutations(review, 2):
        original_train_dataset.append(tag)

# %% [markdown]
# #### <b>라이브러리 불러오기</b>
#
# * 필요한 라이브러리를 불러온다.

# %%
import numpy as np # 데이터 처리를 위한 NumPy 라이브러리 불러오기
import matplotlib.pyplot as plt # 데이터 시각화 라이브러리 불러오기

import torch # PyTorch 라이브러리 불러오기

# %% [markdown]
# #### <b>데이터 세트 및 모델 정의</b>

# %%
import copy
from torch.utils.data.dataset import Dataset


class CustomDataset(Dataset):
    # ① __init__(): 불러올 데이터에 대한 개괄적인 내용
    def __init__(self):
        # 전체 데이터를 담는 리스트
        self.dataset = copy.deepcopy(original_train_dataset)

    # ② __len__(): 현재 데이터 세트에 포함된 총 데이터의 개수
    def __len__(self):
      return len(self.dataset)

    # ③ __getitem__(): 특정한 인덱스에 해당하는 데이터를 반환하는 함수
    def __getitem__(self, idx):
        x = self.dataset[idx][0]
        y = self.dataset[idx][1]

        # 입력 데이터(x)와 출력 데이터(y)를 반환
        return x, y

# %%
train_dataset = CustomDataset()

# %%
print(train_dataset[0][0], train_dataset[0][1])
# Out:
# 1 2

# %%
import torch.nn as nn # PyTorch Neural Networks (nn) 라이브러리


# 태그(tag)에서 특징을 추출하는 인코더 네트워크
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()

        # 267차원 원-핫 인코딩을 2차원의 임베딩으로 변환
        # 원-핫 인코딩: [0, 0, 0, 1, 0, 0, 0, ...] → 차원: 268
        self.layer = nn.Embedding(268, 2)

    # 특징 추출 수행
    def forward(self, x):
        x = self.layer(x)

        return x

# %%
Encoder()
# Out:
# Encoder(
#   (layer): Embedding(268, 2)
# )

# %%
# 특징에서 다시 원본 태그 정보를 복원하는 디코더 네트워크
class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()

        # 다시 2차원의 임베딩을 268차원의 공간으로 매핑
        self.layer = nn.Linear(2, 268)

    # 특징에서 다시 태그(tag) 복원 수행
    def forward(self, x):
        x = self.layer(x)

        return x

# %%
Decoder()
# Out:
# Decoder(
#   (layer): Linear(in_features=2, out_features=268, bias=True)
# )

# %%
# 전체 Word to Vector (Word2Vec) 모델 정의
class Word2Vec(nn.Module):
    def __init__(self):
        super(Word2Vec, self).__init__()

        self.encoder = Encoder() # 인코더 네트워크 초기화
        self.decoder = Decoder() # 디코더 네트워크 초기화

    # 하나의 입력이 주어지면, 인코더와 디코더를 거친 결과를 출력
    def forward(self, x):
        x = self.encoder(x) # 인코더를 이용해 특징 추출
        x = self.decoder(x) # 디코더를 이용해 태그 정보 복원

        return x

# %%
Word2Vec()
# Out:
# Word2Vec(
#   (encoder): Encoder(
#     (layer): Embedding(268, 2)
#   )
#   (decoder): Decoder(
#     (layer): Linear(in_features=2, out_features=268, bias=True)
#   )
# )

# %% [markdown]
# #### <b>딥러닝 모델 학습하기</b>

# %%
import tqdm # 학습 과정 시각화 라이브러리

from torch.utils.data.dataloader import DataLoader
from torch.optim.adam import Adam

train_dataset = CustomDataset() # 학습을 위한 데이터 세트
train_loader = DataLoader(train_dataset, batch_size=1024)

# %%
print(original_train_dataset[0:20])
# Out:
# [(1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2), (4, 5), (4, 1), (4, 6), (4, 7), (5, 4), (5, 1), (5, 6), (5, 7), (1, 4), (1, 5), (1, 6), (1, 7), (6, 4), (6, 5)]

# %%
model = Word2Vec().cuda() # 학습할 전체 모델을 GPU에 업로드

# 하이퍼 파라미터 설정
lr = 0.001
optim = Adam(params=model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

for epoch in range(30):
    iterator = tqdm.tqdm(train_loader) # 학습 과정을 시각화하기 위해 tqdm 사용

    for inputs, targets in iterator:
        # 입력과 출력을 GPU에 업로드
        inputs = inputs.cuda()
        targets = torch.nn.functional.one_hot(targets, num_classes=268)
        targets = targets.type(torch.FloatTensor).cuda()
        pred = model(inputs) # ② 모델에 입력하여 추론 결과 확인
        pred = nn.Softmax(dim=0)(pred)

        loss = criterion(pred, targets) # ③ 모델의 예측 결과와 정답을 비교하여 손실 계산
        loss.backward() # ④ 역전파를 통해 모델의 가중치에 대한 기울기 계산
        optim.step() # ⑤ 계산된 기울기를 이용해 모델 가중치 업데이트

# [Epoch 29] loss: 5.5839362144470215: 100%|██████████| 502/502 [00:04<00:00, 115.45it/s]
# [Epoch 30] loss: 5.583938121795654: 100%|██████████| 502/502 [00:04<00:00, 102.77it/s]

# %%
# 학습된 모델 저장
torch.save(model.state_dict(), "./AE.pt") # 학습된 모델의 가중치를 사전 자료형으로 저장

# %%
# 학습된 모델 성능 평가
model = Word2Vec()
model.load_state_dict(torch.load("./AE.pt"))
model = model.cuda()

# %%
input = torch.Tensor([i]).type(torch.LongTensor).cuda()
print(input.shape)
# Out:
# torch.Size([1])

# %%
features = []

with torch.no_grad():
    for i in range(1, 268):
        input = torch.Tensor([i]).type(torch.LongTensor).cuda()
        feature = model.encoder(input)
        features.append(feature[0].cpu().numpy())

for i in range(1, 268):
    print(i, idx2word[i], features[i - 1])
# Out:
# 1 맞춤 케어를 잘해줘요 [16.067236 -9.417645]
# 2 친절해요 [  0.8804438 -11.93785  ]
# 3 매장이 청결해요 [-8.1773405 10.370701 ]
# 4 주차하기 편해요 [ 6.5117893 -1.60577  ]
# 5 좋은 제품을 사용해요 [-12.990045  14.324648]
# 6 반려동물을 잘 다뤄줘요 [ 5.7493625 -7.3975906]
# 7 시술이 꼼꼼해요 [-13.147782  14.677221]
# 8 원하는 스타일로 잘해줘요 [ 16.991589 -11.436204]
# 9 상담이 자세해요 [16.69204  -9.554464]
# 10 손상이 적어요 [  1.7982157 -13.25756  ]
# 11 트렌디해요 [-3.1967888 10.150814 ]
# 12 음식이 맛있어요 [17.330664   6.3095326]
# 13 재료가 신선해요 [-16.6757     -6.1807575]
# 14 건강한 맛이에요 [ -5.4414515 -16.751434 ]
# 15 뷰가 좋아요 [ 7.279092 15.567213]
# 16 야외 공간이 멋져요 [0.21474168 1.8303906 ]
# 17 특별한 메뉴가 있어요 [-15.098286  -6.602959]
# 18 양이 많아요 [-16.745214 -11.275472]
# 19 가성비가 좋아요 [-12.284507   -4.7531223]
# 20 매장이 넓어요 [-10.730827 -16.60344 ]
# 21 단체모임 하기 좋아요 [-1.387674 16.847145]
# 22 혼밥하기 좋아요 [-4.199916 -2.930002]
# 23 현지 맛에 가까워요 [-5.689586  -1.2301569]
# 24 화장실이 깨끗해요 [-12.575831 -16.236105]
# 25 인테리어가 멋져요 [ -7.05695  -19.325089]
# 26 특별한 날 가기 좋아요 [-4.153242 -1.840929]
# 27 스타일 추천을 잘해줘요 [-2.039183 13.692041]
# 28 관리법을 잘 알려줘요 [-6.5576987  5.8547363]
# 29 대화가 즐거워요 [-6.782413   5.2561126]
# 30 손이 빨라요 [ -5.1429596 -13.457373 ]
# 31 가격이 합리적이에요 [-11.213864 -13.065906]
# 32 고급스러워요 [ -9.121716 -12.374505]
# 33 비싼 만큼 가치있어요 [-3.0698004 -0.5028229]
# 34 종류가 다양해요 [-6.685109 17.920855]
# 35 조용히 쉬기 좋아요 [10.463416 13.574044]
# 36 시설이 깔끔해요 [-9.362012 14.055748]
# 37 학생 관리가 철저해요 [-13.840355   -0.1449245]
# 38 수업이 체계적이에요 [-3.2326522 -7.114214 ]
# 91 할인/적립을 잘 챙겨줘요 [10.238887  -2.4239395]
# 92 취식 공간이 잘 되어있어요 [-11.72929    -4.9856205]
# 93 배달 시스템이 편리해요 [-15.586011  10.853225]
# 94 포장이 깔끔해요 [ -0.19394282 -11.991993  ]
# 95 깨끗해요 [ 12.036224 -17.357162]
# 96 냉난방이 잘돼요 [-11.279218    0.8680142]
# 97 바비큐 해먹기 좋아요 [  5.7697334 -16.035841 ]
# 98 화장실이 잘 되어있어요 [-0.61036676 13.429821  ]
# 99 취사시설이 잘 되어있어요 [-5.751798   6.0758395]
# 100 물놀이하기 좋아요 [  9.768125 -14.684509]
# 101 침구가 좋아요 [-5.4833813  7.360512 ]
# 102 휴게공간이 잘 되어있어요 [0.57827646 4.776766  ]
# 103 공간이 넓어요 [ 15.213828 -13.879817]
# 104 대기 시스템이 편리해요 [10.025374  8.92967 ]
# 105 자세를 꼼꼼히 봐주세요 [2.3466213 1.6881676]
# 106 GX프로그램이 다양해요 [-0.7673262 -5.6752157]
# 107 맛있어요 [ 5.7021995 -4.638247 ]
# 108 손질이 깔끔해요 [-5.0037627  6.1011014]
# 109 신선해요 [ 5.956568 15.428508]
# 110 원산지 표시가 명확해요 [-4.3851647 19.263792 ]
# 111 기구가 다양해요 [ 10.402915 -11.687925]
# 112 선생님 실력이 좋아요 [-8.762355  -7.3683753]
# 113 타석이 넓어요 [-13.0413475  13.88675  ]
# 114 휴게시설이 잘 되어있어요 [ -7.025321 -13.984229]
# 115 수질 관리가 잘돼요 [-2.5141377  3.2151756]
# 116 탕 종류가 다양해요 [12.360355  -1.4867034]
# 117 근처에 갈 곳이 많아요 [  2.718603 -15.531985]
# 118 포장이 정성스러워요 [-11.5834   -11.471479]
# 119 예쁜 소품이 많아요 [-16.55649     7.7235346]
# 120 특색 있는 제품이 많아요 [ 2.4549448 18.358517 ]
# 121 조식이 맛있어요 [-4.181887   1.0605668]
# 122 대중교통이 편해요 [ 10.9346   -12.438137]
# 123 부위가 다양해요 [-4.899071 17.574339]
# 124 복약지도를 잘해줘요 [-12.659131  15.227087]
# 125 제품 종류가 다양해요 [ 13.920844 -11.794496]
# 126 조제약 포장이 세심해요 [  6.76148  -12.785077]
# 127 잡내가 적어요 [ 5.5642757 -6.2032228]
# 128 라이브공연이 훌륭해요 [-3.498301  -1.9734818]
# 129 실내 청소하기 좋아요 [-12.619759 -13.654283]
# 130 다양한 세차용품을 팔아요 [ 10.343958 -10.749223]
# 131 직접 잘 구워줘요 [-4.035625    0.85727966]
# 132 자연스럽게 연출해줘요 [-2.6160347  4.1647854]
# 133 세트장 구성이 다양해요 [-12.901003    3.4893413]
# 134 파우더룸이 잘 되어있어요 [-13.924086 -13.835416]
# 135 소품이 다양해요 [ 0.4612765 14.403308 ]
# 136 룸이 잘 되어있어요 [-3.2070768  0.9177718]
# 137 반찬이 잘 나와요 [7.5584207 7.256788 ]
# 138 와이파이가 잘 돼요 [-11.6744175   9.3909855]
# 139 요금제가 잘 되어있어요 [-14.764761 -15.17952 ]
# 190 매너타임이 잘 지켜져요 [-4.937063 11.482781]
# 191 공용시설 관리가 잘돼요 [-13.630311    5.2324595]
# 192 사이트 간격이 넓어요 [ 9.107598  -1.5160267]
# 193 벌레 걱정 없어요 [14.592118 11.103768]
# 194 전기 사용이 편해요 [ 5.8408628 17.869532 ]
# 195 개수대가 잘 되어있어요 [-12.446552  14.880575]
# 196 맞춤 디자인을 잘해줘요 [ 8.773005 -8.205354]
# 197 눈이 편안해요 [-11.576176  15.174043]
# 198 청결에 신경써줘요 [-1.2327236  0.9212671]
# 199 코스요리가 알차요 [-4.153877  6.04926 ]
# 200 어종이 다양해요 [-8.003166 11.785979]
# 201 독특한 어종이 많아요 [-9.010857  -6.2270584]
# 202 다양한 용품을 팔아요 [-7.784412 -9.61071 ]
# 203 어울려 놀기 좋아요 [-3.4961073 13.699211 ]
# 204 호캉스하기 좋아요 [-10.762356  14.000929]
# 205 디자인이 멋져요 [-14.002761  -11.3353195]
# 206 맞춤 수업을 잘해줘요 [-9.170065  8.670462]
# 207 수업 시간이 충분해요 [-11.814812   2.939745]
# 208 원데이 클래스가 알차요 [12.035943 -4.243288]
# 209 단체로 가기 좋아요 [-12.996269  14.975717]
# 210 프라이빗해요 [-13.252753   -3.6942143]
# 211 관리 효과가 좋아요 [-9.761479 10.359581]
# 212 매물 비교를 잘해줘요 [ 6.094273  -7.5895796]
# 213 남자 머리를 잘해요 [-8.45209  -7.814349]
# 214 예약이 편리해요 [-10.505434  11.626564]
# 215 과도한 권유가 없어요 [-0.74785286 16.456106  ]
# 216 차량 상태가 좋아요 [ 6.472953 -6.198499]
# 217 파티가 재밌어요 [4.53541  4.065741]
# 218 보안시설이 잘 되어있어요 [ -8.4801035 -14.460229 ]
# 219 신간이 빨리 들어와요 [-11.940779 -14.843245]
# 220 책 읽기 쾌적해요 [-8.586314   3.6644993]
# 221 원하는 책을 찾기 쉬워요 [-11.809796 -12.539534]
# 222 카페 같은 분위기에요 [ -9.954334 -12.513123]
# 223 세차를 잘해줘요 [13.680328 12.475062]
# 224 과일이 맛있어요 [ 0.77007985 17.827198  ]
# 225 제철 과일이 빨리 나와요 [-10.767845    2.5479372]
# 226 유익해요 [-18.667828     0.58482283]
# 227 식사하기 좋아요 [ 7.0507865 11.403323 ]
# 228 읽을만한 책이 많아요 [-14.671492 -11.331103]
# 229 트레이닝이 체계적이에요 [ 11.509168 -12.053919]
# 230 아기자기해요 [-11.360851  12.95558 ]
# 231 산모 케어를 잘해줘요 [ 0.16405554 12.069775  ]
# 232 아기 케어를 잘해줘요 [-2.7055569  1.2260442]
# 233 프로그램이 잘 되어있어요 [8.7402   4.933968]
# 234 방 컨디션이 좋아요 [ -8.44924  -15.768412]
# 235 마사지를 잘해줘요 [ 1.663738  -2.1806817]
# 236 병원 연계가 잘 돼있어요 [-10.824369  -7.81523 ]
# 237 식사가 맛있어요 [ -9.443171 -14.329504]
# 238 의료진이 자주 체크해줘요 [ -8.897976 -15.325194]
# 239 가격 안내가 명확해요 [-4.10436   5.627821]
# 240 프린트기가 잘 되어있어요 [ 9.733377 17.965965]
# 241 다양하게 연출하기 좋아요 [  1.0085468 -15.596655 ]
# 242 사진 컨셉이 다양해요 [-10.28844     1.5112218]
# 243 필요한 대화만 오가요 [-9.396106 13.073009]
# 244 수업이 다양해요 [13.830481 15.877232]
# 245 말 교육이 잘 되어있어요 [  8.818088 -11.979746]
# 246 강습 받기 좋아요 [11.731804 11.777705]
# 247 코스가 길어요 [-16.195988  -9.310209]
# 248 독특한 책이 많아요 [-1.2389265   0.14239264]
# 249 사이즈가 다양해요 [-15.871512    6.6618176]
# 250 볼거리가 많아요 [-2.3037987  0.753985 ]
# 251 마사지가 시원해요 [ -3.99879  -11.321305]
# 252 전시 구성이 알차요 [-10.826159  12.770913]
# 253 전시 테마가 재밌어요 [12.330835 12.093209]
# 254 설명이 잘 되어있어요 [-14.674847  14.768023]
# 255 수영장이 잘 되어있어요 [ 9.793135 12.408424]
# 256 수심이 다양해요 [-13.575649 -12.636976]
# 257 조리하기 쉬워요 [ 10.347899 -10.591656]
# 258 조리법 설명이 자세해요 [ 8.149417  -3.1419709]
# 259 클리닉 효과가 좋아요 [4.846266  1.8036988]
# 260 시설이 깨끗해요 [-0.07745964 -1.7933414 ]
# 261 분위기 관리가 철저해요 [-15.011705  13.962886]
# 262 조용해요 [-0.5942574   0.09785168]
# 263 픽업과 반납이 편리해요 [ 17.943447 -16.0449  ]
# 264 차종이 다양해요 [-2.619862    0.75461566]
# 265 샐러드바가 잘 되어있어요 [-12.624248 -13.737928]
# 266 주문제작을 잘해줘요 [  9.7374115 -15.771685 ]
# 267 룸서비스가 잘 되어있어요 [-14.936499  14.545525]

# %% [markdown]
# #### <b>가까운 단어 추출하기</b>

# %%
import numpy as np

target = 1
input = torch.Tensor([target]).type(torch.LongTensor).cuda()
target_feature = model.encoder(input)
target_feature = target_feature[0].detach().cpu().numpy()

print(target, idx2word[target])

close_features = []
for i in range(1, 268):
    feature = features[i - 1]
    distance = np.linalg.norm(np.array(target_feature) - np.array(feature))
    close_features.append([distance, i, idx2word[i]])
close_features.sort()
print(close_features[:5])
# Out:
# 1 맞춤 케어를 잘해줘요
# [[0.0, 1, '맞춤 케어를 잘해줘요'], [0.6238771, 142, '위생적이에요'], [0.6396084, 9, '상담이 자세해요'], [0.937787, 78, '작업이 신속해요'], [1.3580788, 74, '서비스가 좋아요']]

# %%
import numpy as np

target = 30
input = torch.Tensor([target]).type(torch.LongTensor).cuda()
target_feature = model.encoder(input)
target_feature = target_feature[0].detach().cpu().numpy()

print(target, idx2word[target])

close_features = []
for i in range(1, 268):
    feature = features[i - 1]
    distance = np.linalg.norm(np.array(target_feature) - np.array(feature))
    close_features.append([distance, i, idx2word[i]])
close_features.sort()
print(close_features[:5])
# Out:
# 30 손이 빨라요
# [[0.0, 30, '손이 빨라요'], [1.8063122, 182, '위생적으로 케어해줘요'], [1.9547025, 114, '휴게시설이 잘 되어있어요'], [2.423202, 251, '마사지가 시원해요'], [3.3075578, 14, '건강한 맛이에요']]
